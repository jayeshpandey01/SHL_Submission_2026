# %%
# 📘 GRAMMAR SCORING ENGINE NOTEBOOK



## 📄 Project Report

### 🎯 Objective:
# The goal of this project is to develop a **Grammar Scoring Engine** that can evaluate spoken English grammar proficiency from audio recordings. The system transcribes speech to text using OpenAI's Whisper model, extracts linguistic features, and predicts a grammar score between 0–5 using a machine learning model.


### 📦 Pipeline Overview:
# 1. **Audio Transcription:** Using Whisper for high-quality audio-to-text transcription.
# 2. **Text Cleaning & Feature Engineering:** Extract simple statistical text features such as:
#    - Character count
#    - Word count
#    - Average word length
# 3. **Modeling:** Random Forest Regressor is trained on these features to predict grammar score.
# 4. **Evaluation:** RMSE and Pearson Correlation are used to evaluate performance.
# 5. **Prediction:** The trained model is used to predict grammar scores for the test dataset.

# %%
## 1. SETUP & INSTALLATION
# !pip install git+https://github.com/openai/whisper.git
# !pip install transformers torchaudio librosa pandas scikit-learn seaborn matplotlib
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to C:\Users\jayes\AppData\Local\Temp\pip-req-build-0_1sr_bl
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: more-itertools in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai-whisper==20250625) (10.7.0)
# Requirement already satisfied: numba in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai-whisper==20250625) (0.61.2)
# Requirement already satisfied: numpy in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from openai-whisper==20250625) (1.26.4)
# Requirement already satisfied: tiktoken in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai-whisper==20250625) (0.12.0)
# Requirement already satisfied: torch in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai-whisper==20250625) (2.10.0+cpu)
# Requirement already satisfied: tqdm in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai-whisper==20250625) (4.67.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from numba->openai-whisper==20250625) (0.44.0)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tiktoken->openai-whisper==20250625) (2026.2.19)
# Requirement already satisfied: requests>=2.26.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tiktoken->openai-whisper==20250625) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (2022.12.7)
# Requirement already satisfied: filelock in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->openai-whisper==20250625) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->openai-whisper==20250625) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->openai-whisper==20250625) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->openai-whisper==20250625) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->openai-whisper==20250625) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch->openai-whisper==20250625) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sympy>=1.13.3->torch->openai-whisper==20250625) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->torch->openai-whisper==20250625) (3.0.2)
# Requirement already satisfied: colorama in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm->openai-whisper==20250625) (0.4.6)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git 'C:\Users\jayes\AppData\Local\Temp\pip-req-build-0_1sr_bl'
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# Requirement already satisfied: transformers in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.57.1)
# Requirement already satisfied: torchaudio in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.10.0+cpu)
# Requirement already satisfied: librosa in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.11.0)
# Requirement already satisfied: pandas in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.2.1)
# Requirement already satisfied: seaborn in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (3.10.8)
# Requirement already satisfied: filelock in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (2026.2.19)
# Requirement already satisfied: requests in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: torch==2.10.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torchaudio) (2.10.0+cpu)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch==2.10.0->torchaudio) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch==2.10.0->torchaudio) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch==2.10.0->torchaudio) (3.1.6)
# Requirement already satisfied: audioread>=2.1.9 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (0.61.2)
# Requirement already satisfied: scipy>=1.6.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from pandas) (2025.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: six>=1.5 in C:\Users\jayes\AppData\Roaming\Python\Python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: cffi>=1.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sympy>=1.13.3->torch==2.10.0->torchaudio) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->torch==2.10.0->torchaudio) (3.0.2)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
## 2. IMPORT LIBRARIES
import os
import whisper
import pandas as pd
import numpy as np
import librosa
import torch
import torchaudio
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
## 3. LOAD DATASET
train_df = pd.read_csv('dataset/csvs/train.csv')
test_df = pd.read_csv('dataset/csvs/test.csv')
# sample_submission = pd.read_csv('dataset/sample_submission.csv')

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
train_df.head()
# Out:
# Train shape: (409, 2)
# Test shape: (197, 1)
#     filename  label
# 0  audio_173    3.0
# 1  audio_138    3.0
# 2  audio_127    2.0
# 3   audio_95    2.0
# 4   audio_73    3.5

# %%
## 4. LOAD WHISPER MODEL
model = whisper.load_model("base")

# %%
## 5. AUDIO TRANSCRIPTION FUNCTION
def transcribe_audio(file_path):
    try:
        result = model.transcribe(file_path)
        return result['text']
    except Exception as e:
        print(f"Error transcribing {file_path}: {e}")
        return ""

# %%
## 6. TRANSCRIBE TRAINING AUDIO
train_audio_path = "dataset/audios/train"
train_texts = []

for file in tqdm(train_df['filename']):
    # Add .wav extension if not present
    if not file.endswith('.wav'):
        file = f"{file}.wav"
    
    audio_fp = os.path.join(train_audio_path, file).replace("\\", "/")
    
    if not os.path.exists(audio_fp):
        print(f"Missing file: {audio_fp}")
        train_texts.append("")  # Empty string for missing files
        continue
    
    train_texts.append(transcribe_audio(audio_fp))

train_df['transcript'] = train_texts
# Out:
#   0%|          | 0/409 [00:00<?, ?it/s]c:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|██████████| 409/409 [1:15:29<00:00, 11.08s/it]

# %%
# audio_fp = os.path.join(train_audio_path, file).replace("\\", "/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 audio_fp = os.path.join(train_audio_path, file).replace("\\", "/")
#
# NameError: name 'train_audio_path' is not defined

# %%
# train_audio_path = "dataset/audios/train"
# train_texts = []

# for file in tqdm(train_df['filename']):
#     audio_fp = os.path.join(train_audio_path, file).replace("\\", "/")
#     if not os.path.exists(audio_fp):
#         print(f"Missing file: {audio_fp}")
#         train_texts.append(None)
#         continue
#     train_texts.append(transcribe_audio(audio_fp))

# train_df['transcript'] = train_texts
# Out:
# 100%|██████████| 409/409 [00:00<00:00, 4371.92it/s]
# Missing file: dataset/audios/train/audio_173
# Missing file: dataset/audios/train/audio_138
# Missing file: dataset/audios/train/audio_127
# Missing file: dataset/audios/train/audio_95
# Missing file: dataset/audios/train/audio_73
# Missing file: dataset/audios/train/audio_34
# Missing file: dataset/audios/train/audio_120_2
# Missing file: dataset/audios/train/audio_224
# Missing file: dataset/audios/train/audio_342
# Missing file: dataset/audios/train/audio_228
# Missing file: dataset/audios/train/audio_133
# Missing file: dataset/audios/train/audio_223
# Missing file: dataset/audios/train/audio_287
# Missing file: dataset/audios/train/audio_332
# Missing file: dataset/audios/train/audio_158
# Missing file: dataset/audios/train/audio_91
# Missing file: dataset/audios/train/audio_358
# Missing file: dataset/audios/train/audio_79
# Missing file: dataset/audios/train/audio_10
# Missing file: dataset/audios/train/audio_78
# Missing file: dataset/audios/train/audio_313
# Missing file: dataset/audios/train/audio_239
# Missing file: dataset/audios/train/audio_31
# Missing file: dataset/audios/train/audio_74
# Missing file: dataset/audios/train/audio_204
# Missing file: dataset/audios/train/audio_57
# Missing file: dataset/audios/train/audio_369
# Missing file: dataset/audios/train/audio_194
# Missing file: dataset/audios/train/audio_282
# Missing file: dataset/audios/train/audio_105
# Missing file: dataset/audios/train/audio_138_2
# Missing file: dataset/audios/train/audio_212
# Missing file: dataset/audios/train/audio_230
# Missing file: dataset/audios/train/audio_16
# Missing file: dataset/audios/train/audio_249
# Missing file: dataset/audios/train/audio_1
# Missing file: dataset/audios/train/audio_303
# Missing file: dataset/audios/train/audio_317
# Missing file: dataset/audios/train/audio_111
# Missing file: dataset/audios/train/audio_267
# Missing file: dataset/audios/train/audio_85
# Missing file: dataset/audios/train/audio_221
# Missing file: dataset/audios/train/audio_232_2
# Missing file: dataset/audios/train/audio_372
# Missing file: dataset/audios/train/audio_56
# Missing file: dataset/audios/train/audio_269
# Missing file: dataset/audios/train/audio_337
# Missing file: dataset/audios/train/audio_359
# Missing file: dataset/audios/train/audio_43
# Missing file: dataset/audios/train/audio_333
# Missing file: dataset/audios/train/audio_71
# Missing file: dataset/audios/train/audio_40
# Missing file: dataset/audios/train/audio_83
# Missing file: dataset/audios/train/audio_26
# Missing file: dataset/audios/train/audio_195
# Missing file: dataset/audios/train/audio_156
# Missing file: dataset/audios/train/audio_166
# Missing file: dataset/audios/train/audio_361
# Missing file: dataset/audios/train/audio_23
# Missing file: dataset/audios/train/audio_234
# Missing file: dataset/audios/train/audio_47
# Missing file: dataset/audios/train/audio_43_2
# Missing file: dataset/audios/train/audio_354
# Missing file: dataset/audios/train/audio_77
# Missing file: dataset/audios/train/audio_343
# Missing file: dataset/audios/train/audio_58
# Missing file: dataset/audios/train/audio_185
# Missing file: dataset/audios/train/audio_25
# Missing file: dataset/audios/train/audio_18
# Missing file: dataset/audios/train/audio_168
# Missing file: dataset/audios/train/audio_256
# Missing file: dataset/audios/train/audio_32
# Missing file: dataset/audios/train/audio_279
# Missing file: dataset/audios/train/audio_102_2
# Missing file: dataset/audios/train/audio_193
# Missing file: dataset/audios/train/audio_362
# Missing file: dataset/audios/train/audio_321
# Missing file: dataset/audios/train/audio_153
# Missing file: dataset/audios/train/audio_6
# Missing file: dataset/audios/train/audio_46
# Missing file: dataset/audios/train/audio_94
# Missing file: dataset/audios/train/audio_285
# Missing file: dataset/audios/train/audio_109
# Missing file: dataset/audios/train/audio_240_2
# Missing file: dataset/audios/train/audio_248
# Missing file: dataset/audios/train/audio_176
# Missing file: dataset/audios/train/audio_4
# Missing file: dataset/audios/train/audio_19
# Missing file: dataset/audios/train/audio_360_2
# Missing file: dataset/audios/train/audio_194_2
# Missing file: dataset/audios/train/audio_182
# Missing file: dataset/audios/train/audio_64
# Missing file: dataset/audios/train/audio_288
# Missing file: dataset/audios/train/audio_102
# Missing file: dataset/audios/train/audio_115
# Missing file: dataset/audios/train/audio_177
# Missing file: dataset/audios/train/audio_154_2
# Missing file: dataset/audios/train/audio_132
# Missing file: dataset/audios/train/audio_125
# Missing file: dataset/audios/train/audio_226
# Missing file: dataset/audios/train/audio_203
# Missing file: dataset/audios/train/audio_306_2
# Missing file: dataset/audios/train/audio_127_2
# Missing file: dataset/audios/train/audio_263
# Missing file: dataset/audios/train/audio_73_2
# Missing file: dataset/audios/train/audio_76
# Missing file: dataset/audios/train/audio_114
# Missing file: dataset/audios/train/audio_117
# Missing file: dataset/audios/train/audio_17
# Missing file: dataset/audios/train/audio_67
# Missing file: dataset/audios/train/audio_154
# Missing file: dataset/audios/train/audio_8
# Missing file: dataset/audios/train/audio_20
# Missing file: dataset/audios/train/audio_141
# Missing file: dataset/audios/train/audio_363
# Missing file: dataset/audios/train/audio_357
# Missing file: dataset/audios/train/audio_119
# Missing file: dataset/audios/train/audio_109_2
# Missing file: dataset/audios/train/audio_300
# Missing file: dataset/audios/train/audio_238_2
# Missing file: dataset/audios/train/audio_305
# Missing file: dataset/audios/train/audio_61
# Missing file: dataset/audios/train/audio_80
# Missing file: dataset/audios/train/audio_292
# Missing file: dataset/audios/train/audio_324
# Missing file: dataset/audios/train/audio_262
# Missing file: dataset/audios/train/audio_335
# Missing file: dataset/audios/train/audio_110
# Missing file: dataset/audios/train/audio_336_2
# Missing file: dataset/audios/train/audio_174
# Missing file: dataset/audios/train/audio_142
# Missing file: dataset/audios/train/audio_319
# Missing file: dataset/audios/train/audio_254
# Missing file: dataset/audios/train/audio_240
# Missing file: dataset/audios/train/audio_149
# Missing file: dataset/audios/train/audio_251
# Missing file: dataset/audios/train/audio_181
# Missing file: dataset/audios/train/audio_120
# Missing file: dataset/audios/train/audio_199
# Missing file: dataset/audios/train/audio_209
# Missing file: dataset/audios/train/audio_146
# Missing file: dataset/audios/train/audio_246
# Missing file: dataset/audios/train/audio_315
# Missing file: dataset/audios/train/audio_37
# Missing file: dataset/audios/train/audio_140
# Missing file: dataset/audios/train/audio_299
# Missing file: dataset/audios/train/audio_159
# Missing file: dataset/audios/train/audio_302
# Missing file: dataset/audios/train/audio_336
# Missing file: dataset/audios/train/audio_60
# Missing file: dataset/audios/train/audio_112
# Missing file: dataset/audios/train/audio_169
# Missing file: dataset/audios/train/audio_178
# Missing file: dataset/audios/train/audio_7
# Missing file: dataset/audios/train/audio_295
# Missing file: dataset/audios/train/audio_281
# Missing file: dataset/audios/train/audio_151
# Missing file: dataset/audios/train/audio_11
# Missing file: dataset/audios/train/audio_197
# Missing file: dataset/audios/train/audio_104
# Missing file: dataset/audios/train/audio_82
# Missing file: dataset/audios/train/audio_211
# Missing file: dataset/audios/train/audio_250
# Missing file: dataset/audios/train/audio_40_2
# Missing file: dataset/audios/train/audio_328
# Missing file: dataset/audios/train/audio_219
# Missing file: dataset/audios/train/audio_156_2
# Missing file: dataset/audios/train/audio_365
# Missing file: dataset/audios/train/audio_90
# Missing file: dataset/audios/train/audio_196
# Missing file: dataset/audios/train/audio_164
# Missing file: dataset/audios/train/audio_148
# Missing file: dataset/audios/train/audio_235
# Missing file: dataset/audios/train/audio_93
# Missing file: dataset/audios/train/audio_70
# Missing file: dataset/audios/train/audio_124
# Missing file: dataset/audios/train/audio_97
# Missing file: dataset/audios/train/audio_144
# Missing file: dataset/audios/train/audio_311
# Missing file: dataset/audios/train/audio_98
# Missing file: dataset/audios/train/audio_238
# Missing file: dataset/audios/train/audio_69
# Missing file: dataset/audios/train/audio_24
# Missing file: dataset/audios/train/audio_38
# Missing file: dataset/audios/train/audio_145
# Missing file: dataset/audios/train/audio_123
# Missing file: dataset/audios/train/audio_272
# Missing file: dataset/audios/train/audio_183
# Missing file: dataset/audios/train/audio_68
# Missing file: dataset/audios/train/audio_352
# Missing file: dataset/audios/train/audio_220
# Missing file: dataset/audios/train/audio_291
# Missing file: dataset/audios/train/audio_325
# Missing file: dataset/audios/train/audio_232
# Missing file: dataset/audios/train/audio_126
# Missing file: dataset/audios/train/audio_147
# Missing file: dataset/audios/train/audio_350
# Missing file: dataset/audios/train/audio_87
# Missing file: dataset/audios/train/audio_1_2
# Missing file: dataset/audios/train/audio_210
# Missing file: dataset/audios/train/audio_77_2
# Missing file: dataset/audios/train/audio_348
# Missing file: dataset/audios/train/audio_355
# Missing file: dataset/audios/train/audio_341
# Missing file: dataset/audios/train/audio_184
# Missing file: dataset/audios/train/audio_327
# Missing file: dataset/audios/train/audio_290
# Missing file: dataset/audios/train/audio_286
# Missing file: dataset/audios/train/audio_308
# Missing file: dataset/audios/train/audio_130
# Missing file: dataset/audios/train/audio_39
# Missing file: dataset/audios/train/audio_12
# Missing file: dataset/audios/train/audio_276
# Missing file: dataset/audios/train/audio_186
# Missing file: dataset/audios/train/audio_229
# Missing file: dataset/audios/train/audio_113
# Missing file: dataset/audios/train/audio_180
# Missing file: dataset/audios/train/audio_297
# Missing file: dataset/audios/train/audio_275
# Missing file: dataset/audios/train/audio_266
# Missing file: dataset/audios/train/audio_118
# Missing file: dataset/audios/train/audio_58_2
# Missing file: dataset/audios/train/audio_284
# Missing file: dataset/audios/train/audio_181_2
# Missing file: dataset/audios/train/audio_279_2
# Missing file: dataset/audios/train/audio_371
# Missing file: dataset/audios/train/audio_368
# Missing file: dataset/audios/train/audio_165
# Missing file: dataset/audios/train/audio_259
# Missing file: dataset/audios/train/audio_137
# Missing file: dataset/audios/train/audio_155
# Missing file: dataset/audios/train/audio_200
# Missing file: dataset/audios/train/audio_198
# Missing file: dataset/audios/train/audio_369_2
# Missing file: dataset/audios/train/audio_3
# Missing file: dataset/audios/train/audio_233
# Missing file: dataset/audios/train/audio_205
# Missing file: dataset/audios/train/audio_116
# Missing file: dataset/audios/train/audio_356
# Missing file: dataset/audios/train/audio_245
# Missing file: dataset/audios/train/audio_27
# Missing file: dataset/audios/train/audio_121
# Missing file: dataset/audios/train/audio_234_2
# Missing file: dataset/audios/train/audio_225
# Missing file: dataset/audios/train/audio_322
# Missing file: dataset/audios/train/audio_273
# Missing file: dataset/audios/train/audio_323
# Missing file: dataset/audios/train/audio_351
# Missing file: dataset/audios/train/audio_247
# Missing file: dataset/audios/train/audio_128
# Missing file: dataset/audios/train/audio_75
# Missing file: dataset/audios/train/audio_330
# Missing file: dataset/audios/train/audio_30
# Missing file: dataset/audios/train/audio_84
# Missing file: dataset/audios/train/audio_338
# Missing file: dataset/audios/train/audio_108
# Missing file: dataset/audios/train/audio_334
# Missing file: dataset/audios/train/audio_134
# Missing file: dataset/audios/train/audio_298
# Missing file: dataset/audios/train/audio_45
# Missing file: dataset/audios/train/audio_315_2
# Missing file: dataset/audios/train/audio_66
# Missing file: dataset/audios/train/audio_86
# Missing file: dataset/audios/train/audio_243
# Missing file: dataset/audios/train/audio_187
# Missing file: dataset/audios/train/audio_160
# Missing file: dataset/audios/train/audio_13
# Missing file: dataset/audios/train/audio_36
# Missing file: dataset/audios/train/audio_29
# Missing file: dataset/audios/train/audio_171
# Missing file: dataset/audios/train/audio_143
# Missing file: dataset/audios/train/audio_326
# Missing file: dataset/audios/train/audio_278
# Missing file: dataset/audios/train/audio_222
# Missing file: dataset/audios/train/audio_96
# Missing file: dataset/audios/train/audio_52
# Missing file: dataset/audios/train/audio_241
# Missing file: dataset/audios/train/audio_306
# Missing file: dataset/audios/train/audio_312
# Missing file: dataset/audios/train/audio_179
# Missing file: dataset/audios/train/audio_42
# Missing file: dataset/audios/train/audio_318
# Missing file: dataset/audios/train/audio_207
# Missing file: dataset/audios/train/audio_283
# Missing file: dataset/audios/train/audio_255
# Missing file: dataset/audios/train/audio_339
# Missing file: dataset/audios/train/audio_5
# Missing file: dataset/audios/train/audio_257
# Missing file: dataset/audios/train/audio_366
# Missing file: dataset/audios/train/audio_101
# Missing file: dataset/audios/train/audio_227
# Missing file: dataset/audios/train/audio_115_2
# Missing file: dataset/audios/train/audio_214
# Missing file: dataset/audios/train/audio_172
# Missing file: dataset/audios/train/audio_99
# Missing file: dataset/audios/train/audio_293
# Missing file: dataset/audios/train/audio_216
# Missing file: dataset/audios/train/audio_62
# Missing file: dataset/audios/train/audio_48
# Missing file: dataset/audios/train/audio_33
# Missing file: dataset/audios/train/audio_268
# Missing file: dataset/audios/train/audio_201
# Missing file: dataset/audios/train/audio_370
# Missing file: dataset/audios/train/audio_28
# Missing file: dataset/audios/train/audio_367
# Missing file: dataset/audios/train/audio_231
# Missing file: dataset/audios/train/audio_261
# Missing file: dataset/audios/train/audio_289
# Missing file: dataset/audios/train/audio_163
# Missing file: dataset/audios/train/audio_347
# Missing file: dataset/audios/train/audio_139
# Missing file: dataset/audios/train/audio_63
# Missing file: dataset/audios/train/audio_136
# Missing file: dataset/audios/train/audio_129
# Missing file: dataset/audios/train/audio_9
# Missing file: dataset/audios/train/audio_65
# Missing file: dataset/audios/train/audio_301
# Missing file: dataset/audios/train/audio_15
# Missing file: dataset/audios/train/audio_157
# Missing file: dataset/audios/train/audio_41
# Missing file: dataset/audios/train/audio_16_2
# Missing file: dataset/audios/train/audio_226_2
# Missing file: dataset/audios/train/audio_217
# Missing file: dataset/audios/train/audio_280
# Missing file: dataset/audios/train/audio_353
# Missing file: dataset/audios/train/audio_237
# Missing file: dataset/audios/train/audio_208
# Missing file: dataset/audios/train/audio_213
# Missing file: dataset/audios/train/audio_296
# Missing file: dataset/audios/train/audio_256_2
# Missing file: dataset/audios/train/audio_252
# Missing file: dataset/audios/train/audio_195_2
# Missing file: dataset/audios/train/audio_34_2
# Missing file: dataset/audios/train/audio_304
# Missing file: dataset/audios/train/audio_270
# Missing file: dataset/audios/train/audio_202
# Missing file: dataset/audios/train/audio_162
# Missing file: dataset/audios/train/audio_44
# Missing file: dataset/audios/train/audio_218
# Missing file: dataset/audios/train/audio_191
# Missing file: dataset/audios/train/audio_310
# Missing file: dataset/audios/train/audio_260
# Missing file: dataset/audios/train/audio_106
# Missing file: dataset/audios/train/audio_54
# Missing file: dataset/audios/train/audio_2
# Missing file: dataset/audios/train/audio_50
# Missing file: dataset/audios/train/audio_81
# Missing file: dataset/audios/train/audio_206
# Missing file: dataset/audios/train/audio_35
# Missing file: dataset/audios/train/audio_264
# Missing file: dataset/audios/train/audio_92
# Missing file: dataset/audios/train/audio_340
# Missing file: dataset/audios/train/audio_53
# Missing file: dataset/audios/train/audio_346
# Missing file: dataset/audios/train/audio_265
# Missing file: dataset/audios/train/audio_242
# Missing file: dataset/audios/train/audio_14
# Missing file: dataset/audios/train/audio_316
# Missing file: dataset/audios/train/audio_89
# Missing file: dataset/audios/train/audio_274
# Missing file: dataset/audios/train/audio_167
# Missing file: dataset/audios/train/audio_329
# Missing file: dataset/audios/train/audio_26_2
# Missing file: dataset/audios/train/audio_135
# Missing file: dataset/audios/train/audio_307
# Missing file: dataset/audios/train/audio_10_2
# Missing file: dataset/audios/train/audio_320
# Missing file: dataset/audios/train/audio_244
# Missing file: dataset/audios/train/audio_55
# Missing file: dataset/audios/train/audio_364
# Missing file: dataset/audios/train/audio_51
# Missing file: dataset/audios/train/audio_175
# Missing file: dataset/audios/train/audio_190
# Missing file: dataset/audios/train/audio_289_2
# Missing file: dataset/audios/train/audio_188
# Missing file: dataset/audios/train/audio_170
# Missing file: dataset/audios/train/audio_59
# Missing file: dataset/audios/train/audio_49
# Missing file: dataset/audios/train/audio_345
# Missing file: dataset/audios/train/audio_236
# Missing file: dataset/audios/train/audio_253
# Missing file: dataset/audios/train/audio_22
# Missing file: dataset/audios/train/audio_314
# Missing file: dataset/audios/train/audio_161
# Missing file: dataset/audios/train/audio_277
# Missing file: dataset/audios/train/audio_192
# Missing file: dataset/audios/train/audio_56_2
# Missing file: dataset/audios/train/audio_294
# Missing file: dataset/audios/train/audio_344
# Missing file: dataset/audios/train/audio_258
# Missing file: dataset/audios/train/audio_309
# Missing file: dataset/audios/train/audio_150
# Missing file: dataset/audios/train/audio_131
# Missing file: dataset/audios/train/audio_152
# Missing file: dataset/audios/train/audio_360
# Missing file: dataset/audios/train/audio_100
# Missing file: dataset/audios/train/audio_328_2
# Missing file: dataset/audios/train/audio_88
# Missing file: dataset/audios/train/audio_331
# Missing file: dataset/audios/train/audio_215
# Missing file: dataset/audios/train/audio_122
# Missing file: dataset/audios/train/audio_64_2
# Missing file: dataset/audios/train/audio_21
# Missing file: dataset/audios/train/audio_189
# Missing file: dataset/audios/train/audio_72
# Missing file: dataset/audios/train/audio_107
# Missing file: dataset/audios/train/audio_271
# Missing file: dataset/audios/train/audio_349
# Missing file: dataset/audios/train/audio_103

# %%
# ## 6. TRANSCRIBE TRAINING AUDIO
# train_audio_path = "dataset/audios/train"
# train_texts = []

# for file in tqdm(train_df['filename']):
#     audio_fp = os.path.join(train_audio_path, file)
#     train_texts.append(transcribe_audio(audio_fp))

# train_df['transcript'] = train_texts
# Out:
#   0%|          | 0/409 [00:00<?, ?it/s]c:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   1%|          | 4/409 [00:01<01:26,  4.70it/s]
# Error transcribing dataset/audios/train\audio_173: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000002ba1dac4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_173.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_138: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001bb957b4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_138.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_127: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0000018d05d24fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_127.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_95: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000283d1fe4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_95.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_73: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000002794a164fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_73.
# Error opening input files: No such file or directory
#   2%|▏         | 10/409 [00:01<00:36, 10.86it/s]
# Error transcribing dataset/audios/train\audio_34: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001d3082e4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_34.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_120_2: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000266b6784fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_120_2.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_224: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000248e0fa4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_224.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_342: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000271047e4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_342.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_228: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0000020041904fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_228.
# Error opening input files: No such file or directory
#   3%|▎         | 12/409 [00:01<00:32, 12.16it/s]
# Error transcribing dataset/audios/train\audio_133: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0000015abb614fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_133.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_223: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000294b6474fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_223.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_287: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0000029b910c4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_287.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_332: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000234d2a94fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_332.
# Error opening input files: No such file or directory
#   4%|▍         | 17/409 [00:01<00:25, 15.58it/s]
# Error transcribing dataset/audios/train\audio_158: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001750a9f4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_158.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_91: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0000021bad724fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_91.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_358: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000297e7134fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_358.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_79: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000192b8574fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_79.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_10: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000002735ec14fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_10.
# Error opening input files: No such file or directory
#   6%|▌         | 23/409 [00:01<00:20, 19.07it/s]
# ...
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001cce1214fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_21.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_189: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001d5209a4fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_189.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_72: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0000024f55c04fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_72.
# Error opening input files: No such file or directory
# 100%|██████████| 409/409 [00:20<00:00, 19.75it/s]
# Error transcribing dataset/audios/train\audio_107: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 00000263dbf44fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_107.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_271: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001537f144fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_271.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_349: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000002537b644fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_349.
# Error opening input files: No such file or directory
#
# Error transcribing dataset/audios/train\audio_103: Failed to load audio: ffmpeg version 8.0.1-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 000001c234b54fc0] Error opening input: No such file or directory
# Error opening input file dataset/audios/train\audio_103.
# Error opening input files: No such file or directory

# %%
## 7. TRANSCRIBE TEST AUDIO
test_audio_path = "dataset/audios/test"  # Fixed path for local environment
test_texts = []

for file in tqdm(test_df['filename']):
    # Add .wav extension if not present
    if not file.endswith('.wav'):
        file = f"{file}.wav"
    
    audio_fp = os.path.join(test_audio_path, file).replace("\\", "/")
    
    if not os.path.exists(audio_fp):
        print(f"Missing file: {audio_fp}")
        test_texts.append("")  # Empty string for missing files
        continue
    
    test_texts.append(transcribe_audio(audio_fp))

test_df = test_df.copy()
test_df['transcript'] = test_texts
# Out:
#   0%|          | 0/197 [00:00<?, ?it/s]c:\Users\jayes\AppData\Local\Programs\Python\Python311\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|██████████| 197/197 [31:59<00:00,  9.74s/it]

# %%
# ## 7. TRANSCRIBE TEST AUDIO
# test_audio_path = "/content/drive/MyDrive/Colab Notebooks/shl-intern-hiring-assessment/dataset/audios_test"
# test_texts = []

# for file in tqdm(test_df['filename']):
#     audio_fp = os.path.join(test_audio_path, file)
#     transcript = transcribe_audio(audio_fp)
#     test_texts.append(transcript)

# test_df = test_df.copy()
# test_df['transcript'] = test_texts

# %%
## 8. TEXT FEATURE ENGINEERING
def extract_text_features(df):
    df = df.copy()
    df['char_count'] = df['transcript'].apply(lambda x: len(str(x)))
    df['word_count'] = df['transcript'].apply(lambda x: len(str(x).split()))
    df['avg_word_len'] = df['transcript'].apply(lambda x: np.mean([len(w) for w in str(x).split()]) if len(str(x).split()) > 0 else 0)
    return df

train_df = extract_text_features(train_df)
test_df = extract_text_features(test_df)

# %%
# ## 9. MODEL TRAINING (Random Forest Regressor)
# features = ['char_count', 'word_count', 'avg_word_len']
# X_train = train_df[features]

# # Fallback: manually assign grammar scores if missing
# if 'grammar_score' not in train_df.columns:
#     print("'grammar_score' column not found. Assigning random scores for demo purpose.")
#     np.random.seed(42)
#     train_df['grammar_score'] = np.random.uniform(0, 5, size=len(train_df))

# y_train = train_df['grammar_score']
# X_test = test_df[features]

# model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
# model_rf.fit(X_train, y_train)

# y_train_pred = model_rf.predict(X_train)

# %%
## 9. MODEL TRAINING (Random Forest Regressor)
features = ['char_count', 'word_count', 'avg_word_len']
X_train = train_df[features]

# Use 'label' column instead of 'grammar_score'
if 'label' in train_df.columns:
    y_train = train_df['label']
else:
    print("'label' column not found. Cannot train model.")
    raise ValueError("Missing label column")

X_test = test_df[features]

model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)

y_train_pred = model_rf.predict(X_train)

# %%
## 10. EVALUATION METRICS
rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
pearson_corr = np.nan

# Avoid constant input warning
if len(set(y_train)) > 1:
    pearson_corr, _ = pearsonr(y_train, y_train_pred)

print(f"RMSE: {rmse:.4f}")
print(f"Pearson Correlation: {pearson_corr:.4f}")
# Out:
# RMSE: 0.3130
# Pearson Correlation: 0.9469

# %%
## 11. VISUALIZATION
plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_train, y=y_train_pred)

# Add diagonal reference line (perfect predictions)
plt.plot([0, 5], [0, 5], color='red', linestyle='--', label='Perfect Prediction')

# Add labels and title
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.title("Actual vs Predicted Grammar Scores")

# Add metrics as text
plt.text(0.5, 4.5, f"RMSE: {rmse:.2f}\nPearson r: {pearson_corr:.2f}", fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Show legend and grid
plt.legend()
plt.grid(True)
plt.show()

# %%
## 13. PREDICT & SUBMIT
test_preds = model_rf.predict(X_test)
submission = test_df[['filename']].copy()
submission['label'] = test_preds  # Changed from 'grammar_score' to 'label'
submission.to_csv("submission.csv", index=False)

print("Submission file saved as submission.csv")
# Out:
# Submission file saved as submission.csv

# %%
# ## 12. Metrics for final evaluation
# train_df['predicted_score'] = y_train_pred
# train_df['error'] = abs(train_df['grammar_score'] - train_df['predicted_score'])
# outliers = train_df[train_df['error'] > 1.5].sort_values(by='error', ascending=False)

# print("Top Outliers:")
# print(outliers[['filename', 'transcript', 'grammar_score', 'predicted_score', 'error']].head(5))

# %%
## 12. Metrics for final evaluation
train_df['predicted_score'] = y_train_pred
train_df['error'] = abs(train_df['label'] - train_df['predicted_score'])  # Changed from 'grammar_score' to 'label'
outliers = train_df[train_df['error'] > 1.5].sort_values(by='error', ascending=False)

print("Top Outliers:")
print(outliers[['filename', 'transcript', 'label', 'predicted_score', 'error']].head(5))
# Out:
# Top Outliers:
# Empty DataFrame
# Columns: [filename, transcript, label, predicted_score, error]
# Index: []

# %%
## 13. PREDICT & SUBMIT
test_preds = model_rf.predict(X_test)
submission = test_df[['filename']].copy()
submission['grammar_score'] = test_preds
submission.to_csv("submission.csv", index=False)

print("Submission file saved as submission.csv")
# Out:
# Submission file saved as submission.csv
